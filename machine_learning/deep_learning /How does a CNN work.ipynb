# %% [markdown]
# # What does a convolutional neural net actually do when you run it?

# %% [markdown]
# *Say I have a pre-trained convnet image classifier, and I use it to carry out a single classification of one image (“tell me whether this shows a pig, cow, or sheep”) — what does that actually mean, in terms of code?*

# %% [markdown]
# ## What is a network

# %% [markdown]
# It's a **pipeline of functions through which data is passed**, with the output of each function going directly to the input of the next one.
#
# **Each function** is know as a **Layer**

# %% [markdown]
# So to run one classification, we just have to get the image data into the right format and pass it through each layer function in turn, and out pops the network’s best guess.

# %% [markdown]
# ### Layers

# %% [markdown]
# The layers themselves perform some mathematical operation on the data.

# %% [markdown]
#  Some of them do so by making use of a set of other values, provided separately, which they might multiply with the inputs in some way (in which case they are known as weights) or add to the return values (known as biases).

# %% [markdown]
# ** Coming up with suitable weight and bias values for these layers is what training is for.  **

# %% [markdown]
# To train a network, the weights and biases for each such layer are randomly initialised, then the network is repeatedly run to provide classifications of known inputs; each of the network’s guesses is compared with the known class of the input, and the weights and biases of the network are updated depending on how accurate the classification was. Eventually, with luck, they will converge on some reliable values. Training is both difficult and tedious, so here we will happily leave it to machine-learning researchers.

# %% [markdown]
# These trainable layers are then typically sandwiched by fixed layers that provide non-linearities (also known as activation functions) and various data-manipulation bits and bobs like max-pooling. More on these later.

# %% [markdown]
# ** The layers are pure functions: a layer with a given set of weights and biases will always produce the same output for a given input. **

# %% [markdown]
# ![understand_cnn_network.jpg](attachment:understand_cnn_network.jpg)

# %% [markdown]
# ### Tensors

# %% [markdown]
# For our purposes a tensor is a multidimensional array of numbers

# %% [markdown]
# A tensor has a shape, which we can write as a list of sizes, and the length of that list is the rank

# %% [markdown]
# A matrix is a rank-2 tensor whose shape has two values, height and width. The matrix \begin{bmatrix}1.0&3.0&5.0\\2.0&4.0&6.0\end{bmatrix} has shape [2, 3], if we are giving the height first.

# %% [markdown]
# A C++ vector of floats is a rank-1 tensor, whose shape is a list of one value, the number of elements in the vector. The vector { 1.0, 2.0, 3.0 } has the shape [3].

# %% [markdown]
# A single number can also be considered a tensor, of rank 0, with shape [].

# %% [markdown]
# ### Layers used in our model

# %% [markdown]
# # Source

# %% [markdown]
#  * https://thebreakfastpost.com/2018/04/18/what-does-a-convolutional-neural-net-actually-do-when-you-run-it/#ampshare=https://thebreakfastpost.com/2018/04/18/what-does-a-convolutional-neural-net-actually-do-when-you-run-it/
