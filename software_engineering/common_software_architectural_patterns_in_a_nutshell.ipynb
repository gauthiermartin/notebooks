# %% [markdown]
# # 10 Common Software Architectural Patterns in a nutshell

# %% [markdown]
# * Choose suitable software architecture before choosing application architecture.

# %% [markdown]
# ## What is an Architectural Pattern?

# %% [markdown]
# An **Architectural Pattern** is a general solution to a commonly occurring problem in software architecture within a given context.

# %% [markdown]
# Architectural Pattern are similar to software design pattern but have a broader scopre.

# %% [markdown]
# ## 1.Layered Pattern

# %% [markdown]
# * Can be used to structure programs that can be **decomposed into a group of substasks**, each of which is at a particular level of abstraction.**Each layer provides services to the next higher layer**.

# %% [markdown]
# The most commonly found layers of a general information system are :

# %% [markdown]
# * Presentation Layer (UI Layer)
# * Application Layer (Service Layer)
# * Business logic layer (Domain Layer)
# * Data access layer (Persitence layer)

# %% [markdown]
# Usage :

# %% [markdown]
# * General desktop applications
# * E commerce web applications

# %% [markdown]
# ![layered_pattern.png](attachment:layered_pattern.png)

# %% [markdown]
# ## 2.Client-server pattern

# %% [markdown]
# This pattern consist of two parties. The server and his multiple clients. The services is provided to the multiple clients by the server. Clients request services from the server and the server provide the relevant services to the client.Meanwhile the server continues to listen for client requests.

# %% [markdown]
# Usage:

# %% [markdown]
# * Online applications such as email, document sharing and banking.

# %% [markdown]
# ![client_server_pattern.png](attachment:client_server_pattern.png)

# %% [markdown]
# ## 3.Master-slave pattern

# %% [markdown]
# * This pattern consists of two parties. **Master** and **Slaves**.
# * **The master component distrubutes the work among identical slave components, and computes a final result from the results which the slaves return**

# %% [markdown]
# Usage:

# %% [markdown]
# * In database replication (master is the source & slave are synchronized to it)
# * Peripheals connected to a bus in a computer system

# %% [markdown]
# ![master_slave.png](attachment:master_slave.png)

# %% [markdown]
# ## 4. Pipe-filter pattern

# %% [markdown]
# This pattern can be used for system which produce or process a stream of data.

# %% [markdown]
# Each processing step is enclosed within a **filter** component.

# %% [markdown]
# Data to be processed is passed through **pipes**.These pipes can be used for buffering or synchronization proposes.

# %% [markdown]
# Usage:

# %% [markdown]
# * Compilers. The consecutive filters perform lexical analysis, parsing semetantic analysis, and code generation
# * Workflow in bioinformatics.

# %% [markdown]
# ![pipe-filter.png](attachment:pipe-filter.png)

# %% [markdown]
# # 5. Broker Pattern

# %% [markdown]
# This pattern is used to structure distributed system with decoupled components. These components can interact with each other by remote service invocations.A **broker** component is responsible for the coordination of communication among **components**

# %% [markdown]
# Servers publish their capabilites (services and characteristics) to a broker. Clients request a service from the broker , and the broker then redirects the client to a suitable service from its registery.

# %% [markdown]
# Usage:

# %% [markdown]
# * Message broker software such as ApacheMQ, Apache Kafka, RabbitMQ, Redis

# %% [markdown]
# ![broker.png](attachment:broker.png)

# %% [markdown]
# # Source

# %% [markdown]
# * https://towardsdatascience.com/10-common-software-architectural-patterns-in-a-nutshell-a0b47a1e9013
