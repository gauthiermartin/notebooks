# %% [markdown]
# # An Intuitive Guide to Deep Network Architectures

# %% [markdown]
# ![1*_rCyzi7fQzc_Q1gCqSLM1g.png](attachment:1*_rCyzi7fQzc_Q1gCqSLM1g.png)

# %% [markdown]
# ## How and why do these models work ?

# %% [markdown]
# ### The building blocks

# %% [markdown]
# * ResNet
# * Inception
# * Xception

# %% [markdown]
# ### The birth of ResNet

# %% [markdown]
# Why do very deep nets perform worse as you keep adding layers?
